# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir("C:\\Users\\Aulbek\\Рабочий стол\\DjangoProjects\\archive")

channels = pd.read_csv("C:\\Users\\Aulbek\\Рабочий стол\\DjangoProjects\\archive\\channels.csv",encoding='utf-8',errors='ignore')
deliveries = pd.read_csv("C:\\Users\\Aulbek\\Рабочий стол\\DjangoProjects\\archive\\deliveries.csv",encoding='utf-8')
drivers = pd.read_csv("C:\\Users\\Aulbek\\Рабочий стол\\DjangoProjects\\archive\\drivers.csv",encoding='utf-8')
hubs = pd.read_csv("C:\\Users\\Aulbek\\Рабочий стол\\DjangoProjects\\archive\\hubs.csv",encoding='utf-8')
orders = pd.read_csv("C:\\Users\\Aulbek\\Рабочий стол\\DjangoProjects\\archive\\orders.csv",encoding='utf-8')
payments = pd.read_csv("C:\\Users\\Aulbek\\Рабочий стол\\DjangoProjects\\archive\\payments.csv",encoding='utf-8')
stores = pd.read_csv("C:\\Users\\Aulbek\\Рабочий стол\\DjangoProjects\\archive\\stores.csv",encoding='utf-8')
df_combined = pd.concat([channels,deliveries,drivers,hubs,orders,payments,stories])
print(df_combined.head())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File parsers.pyx:1120, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File parsers.pyx:1272, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File parsers.pyx:1285, in pandas._libs.parsers.TextReader._string_convert()
#
# File parsers.pyx:1535, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc3 in position 1: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[51], line 6
#       4 deliveries = pd.read_csv("C:\\Users\\Aulbek\\Рабочий стол\\DjangoProjects\\archive\\deliveries.csv",encoding='utf-8')
#       5 drivers = pd.read_csv("C:\\Users\\Aulbek\\Рабочий стол\\DjangoProjects\\archive\\drivers.csv",encoding='utf-8')
# ...

# %%
new_df = df.fillna(0)
new_df
# Out:
#         delivery_id  delivery_order_id  driver_id  delivery_distance_meters  \
# 0           2174658           68413340     8378.0                    5199.0
# 1           2174660           68414309     2473.0                     410.0
# 2           2174661           68416230     7615.0                    3784.0
# 3           2174663           68412721     8378.0                    5714.0
# 4           2174675           68414018    10463.0                    3746.0
# ...             ...                ...        ...                       ...
# 378838      3134825           87083078     7615.0                    8110.0
# 378839      3135417           87660079    26223.0                   14454.0
# 378840      3135849           82340127    55429.0                    2546.0
# 378841      3142829           88586792    47016.0                    3106.0
# 378842      3144739           93026454    10504.0                    2919.0
#
#        delivery_status
# 0            DELIVERED
# ...
